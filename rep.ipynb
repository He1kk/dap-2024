# %% [markdown]
# <a href="https://colab.research.google.com/github/He1kk/dap-2024/blob/main/rep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Лабараторная работа №1 Подготовка среды для анализа данных.
#
# Задания:
# 1. Создайте учетную запись в сервисе GitHub
# 2. Выполните форк репозитория https://github.com/chebotarevsa/dap-2024
# 3. Создайте учетную запись в Google Colab
# 4. Настройте интеграцию Google Colab и GitHub
# 5. Создайте в Google Colab отчет о выполненой работе в виде файла rep.ipynb. Используйте Markdown разметку (заголовки, списки, форматированный текст, ссылки)
# 6. Сохраните отчет в ваш репозиторий github в директории ./les01
#
# Выполнение заданий:
# 1. Создан аккаунт в github.
# ![image.png](data:image/png;base64,...)
# 2. Выполнен форк репозитория.
# ![image.png](data:image/png;base64,...)
# 3. Создан аккаунт в google colab.
# ![image.png](data:image/png;base64,...)
# 4. Привязал аккаунт google colab к gitbuh.
# ![image.png](data:image/png;base64,...)
# 5. Отчет создан и сохранен в github
